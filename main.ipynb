# %% [markdown]
# ## dataset stuff

# %%
import pandas as pd
df = pd.read_csv('dataset.csv')

# %%
# formatting
df = df.drop("student_id", axis=1)

# %%
from sklearn.utils import shuffle
df = shuffle(df)

# %%
# Display the first few rows of the dataset to verify its contents
df
# Out:
#        age  gender  course  study_hours  class_attendance internet_access  \
# 18634   23   other    b.sc         6.50              77.7              no
# 12355   19   other   b.com         0.55              75.1             yes
# 1260    19  female      ba         2.87              80.1             yes
# 6975    22    male     bca         3.81              68.2             yes
# 19479   22    male      ba         3.14              86.4             yes
# ...    ...     ...     ...          ...               ...             ...
# 4918    23  female   b.com         4.66              93.7             yes
# 9317    21  female   b.com         2.55              82.2             yes
# 416     24   other     bba         4.36              69.6             yes
# 3806    17    male  b.tech         2.31              71.6             yes
# 7674    24   other    b.sc         2.05              89.3             yes
#
#        sleep_hours sleep_quality   study_method facility_rating  \
# 18634          7.7          good    group study             low
# 12355          6.3          good  online videos             low
# 1260           7.0          good     self-study             low
# 6975           7.9          poor    group study            high
# 19479          7.7          poor          mixed             low
# ...            ...           ...            ...             ...
# 4918           5.3          good          mixed            high
# 9317           4.9       average          mixed             low
# 416            8.6       average     self-study            high
# 3806           9.6       average          mixed            high
# 7674           6.1          good     self-study          medium
#
#       exam_difficulty  exam_score
# 18634        moderate        84.2
# 12355        moderate        52.8
# 1260             easy        75.4
# 6975             easy        66.6
# 19479        moderate        61.9
# ...               ...         ...
# 4918         moderate        92.3
# 9317         moderate        40.4
# 416          moderate        76.0
# 3806         moderate        61.9
# 7674             hard        52.9
#
# [20000 rows x 12 columns]

# %% [markdown]
# ## tensorflow model prep

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from keras import *

from keras.models import Sequential
from keras.layers import Dense, Activation
# Out:
# 2025-12-19 15:28:17.882018: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-12-19 15:28:28.055135: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# /usr/local/python/3.12.1/lib/python3.12/site-packages/keras/src/export/tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):

# %%
# example data for the XOR
X = np.array([[0,0],[0,1],[1,0],[1,1]])
y = np.array([[0],[1],[1],[0]])

# %%
model = Sequential()
model.add(Activation('tanh'))
model.add(Dense(1))
model.add(Activation('sigmoid'))
