# %% [markdown]
# ## dataset stuff

# %%
import pandas as pd
df = pd.read_csv('dataset.csv')

# %%
# formatting
df = df.drop("student_id", axis=1)

# %%
from sklearn.utils import shuffle
df = shuffle(df)

# %%
# Display the first few rows of the dataset to verify its contents
df.head()
# Out:
#        age  gender course  study_hours  class_attendance internet_access  \
# 12110   19   other  b.com         0.20              55.4             yes
# 18823   19    male    bca         7.16              59.2             yes
# 3628    23    male     ba         3.48              67.8              no
# 9512    20    male     ba         6.98              79.0             yes
# 8225    23  female    bca         4.50              48.6              no
#
#        sleep_hours sleep_quality   study_method facility_rating  \
# 12110          9.1          poor  online videos            high
# 18823          8.2          good       coaching          medium
# 3628           9.6          good    group study             low
# 9512           4.4          poor    group study            high
# 8225           4.9          poor    group study             low
#
#       exam_difficulty  exam_score
# 12110        moderate        29.2
# 18823        moderate        81.9
# 3628         moderate        66.1
# 9512         moderate        81.7
# 8225         moderate        53.3

# %% [markdown]
# ## tensorflow model prep

# %%
import tensorflow as tf
from tensorflow import keras
from keras import *
# Out:
# /usr/local/python/3.12.1/lib/python3.12/site-packages/keras/src/export/tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):
